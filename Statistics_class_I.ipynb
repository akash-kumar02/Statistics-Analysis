# %%
# libraries to wprk with
import pandas as pd
import numpy as np

# %%
# data
df=pd.read_csv('Fortune500(1).csv')

# %%
# first five rows
df.head()
# Out:
#    Rank               Title  Employees       Sector  \
# 0     1             Walmart    2300000    Retailing
# 1     2  Berkshire Hathaway     367700   Financials
# 2     3               Apple     116000   Technology
# 3     4         Exxon Mobil      72700       Energy
# 4     5            McKesson      68000  Wholesalers
#
#                                    Industry         Hqcity  \
# 0                     General Merchandisers    Bentonville
# 1  Insurance: Property and Casualty (Stock)          Omaha
# 2               Computers, Office Equipment      Cupertino
# 3                        Petroleum Refining         Irving
# 4                  Wholesalers: Health Care  San Francisco
#
#                    Ceo                                      Ceo-title  \
# 0  C. Douglas McMillon  President, Chief Executive Officer & Director
# 1    Warren E. Buffett             Chairman & Chief Executive Officer
# 2      Timothy D. Cook             Chief Executive Officer & Director
# ...

# %%
# last five rows
df.tail()
# Out:
#      Rank           Title  Employees                      Sector  \
# 495   496   Michaels Cos.      31000                   Retailing
# 496   497   Toll Brothers       4200  Engineering & Construction
# 497   498           Yahoo       8500                  Technology
# 498   499   Vistra Energy       4431                      Energy
# 499   500  ABM Industries     110000           Business Services
#
#                              Industry     Hqcity                     Ceo  \
# 495        Specialty Retailers: Other     Irving           Carl S. Rubin
# 496                      Homebuilders    Horsham  Douglas C. Yearley Jr.
# 497   Internet Services and Retailing  Sunnyvale        Marissa A. Mayer
# 498                            Energy     Dallas        Curtis A. Morgan
# 499  Diversified Outsourcing Services   New York        Scott B. Salmirs
#
#                                          Ceo-title  Revenues  Revchange  \
# ...

# %%
# rows and columns
df.shape
# Out:
# (500, 13)

# %%
# info about columns (very imp)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        500 non-null    int64
#  1   Title       500 non-null    object
#  2   Employees   500 non-null    int64
#  3   Sector      500 non-null    object
#  4   Industry    500 non-null    object
#  5   Hqcity      500 non-null    object
#  6   Ceo         500 non-null    object
#  7   Ceo-title   500 non-null    object
#  8   Revenues    500 non-null    int64
#  9   Revchange   500 non-null    float64
#  10  Profits     500 non-null    float64
#  11  Prftchange  500 non-null    object
#  12  Assets      500 non-null    int64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 50.9+ KB

# %%
# creating a dataset
sub_df=df[['Rank','Title','Employees','Sector','Revenues','Profits']]

# %%
sub_df.head()
# Out:
#    Rank               Title  Employees       Sector  Revenues  Profits
# 0     1             Walmart    2300000    Retailing    485873  13643.0
# 1     2  Berkshire Hathaway     367700   Financials    223604  24074.0
# 2     3               Apple     116000   Technology    215639  45687.0
# 3     4         Exxon Mobil      72700       Energy    205004   7840.0
# 4     5            McKesson      68000  Wholesalers    192487   2258.0

# %%
sub_df.tail()
# Out:
#      Rank           Title  Employees                      Sector  Revenues  \
# 495   496   Michaels Cos.      31000                   Retailing      5197
# 496   497   Toll Brothers       4200  Engineering & Construction      5170
# 497   498           Yahoo       8500                  Technology      5169
# 498   499   Vistra Energy       4431                      Energy      5164
# 499   500  ABM Industries     110000           Business Services      5145
#
#      Profits
# 495    378.2
# 496    382.1
# 497   -214.3
# 498   -214.3
# 499     57.2

# %%
sub_df.tail(10)
# Out:
#      Rank                      Title  Employees                      Sector  \
# 490   491              Liberty Media       3626                       Media
# 491   492           Rockwell Collins      19000         Aerospace & Defense
# 492   493  Robert Half International      16400           Business Services
# 493   494                  CH2M Hill      20000  Engineering & Construction
# 494   495                   Big Lots      23150                   Retailing
# 495   496              Michaels Cos.      31000                   Retailing
# 496   497              Toll Brothers       4200  Engineering & Construction
# 497   498                      Yahoo       8500                  Technology
# 498   499              Vistra Energy       4431                      Energy
# 499   500             ABM Industries     110000           Business Services
#
#      Revenues  Profits
# 490      5276    680.0
# 491      5259    728.0
# 492      5250    343.4
# 493      5236     15.0
# ...

# %%
sub_df.describe()
# Out:
#              Rank     Employees       Revenues       Profits
# count  500.000000  5.000000e+02     500.000000    500.000000
# mean   250.492000  5.635013e+04   24111.748000   1779.479800
# std    144.477366  1.234520e+05   38337.353337   3937.558721
# min      1.000000  8.300000e+01    5145.000000  -6177.000000
# 25%    125.750000  1.190000e+04    7245.000000    235.725000
# 50%    250.500000  2.500000e+04   11384.000000    683.600000
# 75%    375.250000  5.682525e+04   22605.250000   1770.775000
# max    500.000000  2.300000e+06  485873.000000  45687.000000

# %%
mean_rev=sub_df['Revenues'].mean()
mean_rev
# Out:
# 24111.748

# %%
print(mean_rev)
# Out:
# 24111.748

# %%
med_rev=sub_df['Revenues'].median()
med_rev
# Out:
# 11384.0

# %%
mode_rev=sub_df['Revenues'].mode()
mode_rev
# Out:
# 0    9061
# Name: Revenues, dtype: int64

# %%
s=sub_df['Revenues'].min()
s
# Out:
# 5145

# %%
l=sub_df['Revenues'].max()
l
# Out:
# 485873

# %%
range=sub_df['Revenues'].max()-sub_df['Revenues'].min()
range
# Out:
# 480728

# %%
range=l-s
range
# Out:
# 480728

# %%
sd=sub_df['Revenues'].std()
sd
# Out:
# 38337.35333653324

# %%
var=sub_df['Revenues'].var()
var
# Out:
# 1469752660.8501961

# %%
# Quantile
# P75=Q3 and P25=Q1
q1=sub_df['Revenues'].quantile(0.25)
q1
# Out:
# 7245.0

# %%
q3=sub_df['Revenues'].quantile(0.75)
q3
# Out:
# 22605.25

# %%
iqr=q3-q1
iqr
# Out:
# 15360.25

# %%
# OR
iqr2=sub_df['Revenues'].quantile(0.75)-sub_df['Revenues'].quantile(0.25)
iqr2
# Out:
# 15360.25

# %%
skew=sub_df['Revenues'].skew()
skew
# Out:
# 5.480066970305041

# %%
# calculate CV for the revenues colums
# cv=(sd/mean)*100

# %%
cv1=sub_df['Revenues'].std()/sub_df['Revenues'].mean()*100
cv1
# Out:
# 158.99864803055027

# %%
cv2=sub_df['Profits'].std()/sub_df['Profits'].mean()*100
cv2
# Out:
# 221.2758313353473

# %%
print("The CV of Revenues column is",cv1,"%")
# Out:
# The CV of Revenues column is 158.99864803055027 %

# %%
#  For randomly find
sub_df.sample()
# Out:
#      Rank                   Title  Employees                     Sector  \
# 108   109  Mondelez International      90000  Food, Beverages & Tobacco
#
#      Revenues  Profits
# 108     25923   1659.0

# %%
sub_df.sample(5)
# Out:
#      Rank                 Title  Employees                         Sector  \
# 427   428             Alleghany       3420                     Financials
# 19     20            Fannie Mae       7000                     Financials
# 426   427       TreeHouse Foods      16027      Food, Beverages & Tobacco
# 130   131             Starbucks     254000  Hotels, Restaurants & Leisure
# 146   147  Bristol-Myers Squibb      25000                    Health Care
#
#      Revenues  Profits
# 427      6131    456.9
# 19     107162  12313.0
# 426      6175   -228.6
# 130     21316   2817.7
# 146     19427   4457.0

# %%
# By percentage
sub_df.sample(frac=0.01)
# Out:
#      Rank                            Title  Employees  \
# 450   451         Citizens Financial Group      17600
# 368   369                          Hershey      17140
# 377   378            Alliance Data Systems      17000
# 314   315  American Family Insurance Group      10471
# 38     39                      Freddie Mac       5982
#
#                         Sector  Revenues  Profits
# 450                 Financials      5763   1045.0
# 368  Food, Beverages & Tobacco      7440    720.0
# 377          Business Services      7138    515.8
# 314                 Financials      8829    325.6
# 38                  Financials     65665   7815.0

# %%
df_sample=sub_df.sample(frac=0.70)
mean2=df_sample['Revenues'].mean()
print(mean2)
# Out:
# 21515.46

# %%
df_sample=sub_df.sample(frac=0.70,random_state=0)
mean3=df_sample['Revenues'].mean()
print(mean3)
# Out:
# 24044.977142857144

# %%
df_sample=sub_df.sample(frac=0.70,random_state=1)
mean4=df_sample['Revenues'].mean()
print(mean4)
# Out:
# 23581.79142857143

# %%
df_sample=sub_df.sample(frac=0.70,random_state=1)
m=df_sample['Revenues'].mean()
print(m)
# Out:
# 23581.79142857143

# %%
# select 70% random rows from the dataset and consider this a sample. calculate mean of this sample w.r.t profit.repeat the process 5 time
# commute the diff btw mean and each mean separtely . tabulate your observation.

# %%
df_sample=sub_df.sample(frac=0.7,random_state=0)
m1=df_sample['Profits'].mean()
print(m1)
# Out:
# 1855.4874285714288

# %%
df_sample=sub_df.sample(frac=0.7,random_state=1)
m2=df_sample['Profits'].mean()
print(m2)
# Out:
# 1634.9054285714287

# %%
df_sample=sub_df.sample(frac=0.7,random_state=2)
m3=df_sample['Profits'].mean()
print(m3)
# Out:
# 1683.4168571428572

# %%
df_sample=sub_df.sample(frac=0.7,random_state=3)
m4=df_sample['Profits'].mean()
print(m4)
# Out:
# 1573.515142857143

# %%
df_sample=sub_df.sample(frac=0.7,random_state=4)
m5=df_sample['Profits'].mean()
print(m5)
# Out:
# 1876.998857142857

# %%
# total mean of profits
mean_pro=sub_df['Profits'].mean()
mean_pro
# Out:
# 1779.4797999999998

# %%
diff1=mean_pro-m1
print(diff1)
# Out:
# -76.007628571429

# %%
diff2=mean_pro-m2
print(diff2)
# Out:
# 144.5743714285711

# %%
diff3=mean_pro-m3
print(diff3)
# Out:
# 96.06294285714262

# %%
diff4=mean_pro-m4
print(diff4)
# Out:
# 205.96465714285682

# %%
diff5=mean_pro-m5
print(diff5)
# Out:
# -97.51905714285726

# %%
diff=mean_pro-(m1+m2+m3+m4+m5)
print(diff)
# Out:
# -6844.843914285714

# %%
q1=sub_df['Revenues'].quantile(0.25)
q1
# Out:
# 7245.0

# %%
q3=sub_df['Revenues'].quantile(0.75)
q3
# Out:
# 22605.25

# %%
iqr=q3-q1
iqr
# Out:
# 15360.25

# %%
lower_limit=q1-1.5*iqr
lower_limit
# Out:
# -15795.375

# %%
upper_limit=q3+1.5*iqr
upper_limit
# Out:
# 45645.625

# %%
outliers=sub_df[(sub_df["Revenues"]<lower_limit) | (sub_df["Revenues"]>upper_limit)]
print("Outlier Rows:")
outliers
# Out:
# Outlier Rows:
#     Rank                       Title  Employees          Sector  Revenues  \
# 0      1                     Walmart    2300000       Retailing    485873
# 1      2          Berkshire Hathaway     367700      Financials    223604
# 2      3                       Apple     116000      Technology    215639
# 3      4                 Exxon Mobil      72700          Energy    205004
# 4      5                    McKesson      68000     Wholesalers    192487
# ..   ...                         ...        ...             ...       ...
# 57    58                       FedEx     335767  Transportation     50365
# 58    59  Hewlett Packard Enterprise     195000      Technology     50123
# 59    60               Cisco Systems      73700      Technology     49247
# 60    61                          HP      49000      Technology     48238
# 61    62                Dow Chemical      56000       Chemicals     48158
#
#     Profits
# 0   13643.0
# 1   24074.0
# 2   45687.0
# ...

# %%
q1_pro=sub_df['Profits'].quantile(0.25)
q1_pro
# Out:
# 235.725

# %%
q3_pro=sub_df['Profits'].quantile(0.75)
q3_pro
# Out:
# 1770.775

# %%
iqr_pro=q3_pro-q1_pro
iqr_pro
# Out:
# 1535.0500000000002

# %%
lower_limit_pro=q1_pro-1.5*iqr_pro
lower_limit_pro
# Out:
# -2066.8500000000004

# %%
upper_limit_pro=q3_pro+1.5*iqr_pro
upper_limit_pro
# Out:
# 4073.3500000000004

# %%
outliers_pro=sub_df[(sub_df["Profits"]<lower_limit_pro) | (sub_df["Profits"]>upper_limit_pro)]
print("Outlier Rows:")
outliers_pro
# Out:
# Outlier Rows:
#      Rank                   Title  Employees       Sector  Revenues  Profits
# 0       1                 Walmart    2300000    Retailing    485873  13643.0
# 1       2      Berkshire Hathaway     367700   Financials    223604  24074.0
# 2       3                   Apple     116000   Technology    215639  45687.0
# 3       4             Exxon Mobil      72700       Energy    205004   7840.0
# 5       6      UnitedHealth Group     230000  Health Care    184840   7017.0
# ..    ...                     ...        ...          ...       ...      ...
# 284   285            Baker Hughes      33000       Energy      9841  -2738.0
# 309   310                    eBay      12600   Technology      8979   7266.0
# 342   343       Chesapeake Energy       3300       Energy      7872  -4401.0
# 343   344      Anadarko Petroleum       4500       Energy      7869  -3071.0
# 374   375  National Oilwell Varco      36384       Energy      7251  -2412.0
#
# [68 rows x 6 columns]

# %%
sum_rev=df["Revenues"].sum()
sum_rev
# Out:
# 12055874

# %%
n=len(sub_df)
n
# Out:
# 500

# %%
mean_rev=sum_rev/n
mean_rev
# Out:
# 24111.748

# %%
d=(df["Revenues"]-mean_rev)**2
d
# Out:
# 0      2.132235e+11
# 1      3.979716e+10
# 2      3.668269e+10
# 3      3.272201e+10
# 4      2.835023e+10
#            ...
# 495    3.577677e+08
# 496    3.587898e+08
# 497    3.588277e+08
# 498    3.590172e+08
# 499    3.597375e+08
# Name: Revenues, Length: 500, dtype: float64

# %%
sum_d=d.sum()
sum_d
# Out:
# 733406577764.248

# %%
std_dev=(sum_d/n)**(1/2)
std_dev
# Out:
# 38298.996795327366
